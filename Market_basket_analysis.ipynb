# %% [markdown]
# Market basket analysis is an association analysis method used to identify an association between different itemset then find frequent patterns in a database, D.<br>
# Support is the percentage of transactions in D that contains A union B, P(A u B).<br>
# Confidence is the percentage of transactions in D that containing A that also contains B, P(A|B).<br>
# Rules that are considered strong, are those that satisfy both a minimum support(min sup) and a minimum confidence(min conf).<br>
# Different algorithms used in market basket analysis are apriori, FP growth, SETM, AIS. For this particular analysis, we will be using the Apriori algorithm.<br>
# Steps involved in working with Apriori algorithm:<br>
# -Define the min sup and min conf<br>
# -Find all subsets in the database with higher support than the min sup<br>
# -Find all rules for thtse subsets with higher confidence than min conf<br>
# -Sort these association rules in decreasing order<br>
# -Analyze these rules along with their support and confidence<br>
#
# A store dataset readily available on Kaggle will be used for this analysis

# %%
import pandas as pd
import numpy as np
from apyori import apriori

# %%
#Header is set to none because the dataset has no header
df=pd.read_csv("/Users/bambino/Documents/DATASETS/Market_Basket_Optimisation.csv",header=None)

# %%
df.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
df.shape
# Out:
# (7501, 20)

# %%
#creating a list of items in every transaction
lst=[]
for a in range(1,7501):
    lst.append([str(df.values[a,b]) for b in range(0,20)])

# %%
#aprori algorithm
rules=apriori(lst,min_support=0.0045,min_confidence=0.2,min_lift=3,min_length=2)
results=list(rules)

# %%
len(results)
# Out:
# 48

# %%
for s in range(0,len(results)):
    print(results[s][0])
# Out:
# frozenset({'chicken', 'light cream'})
# frozenset({'mushroom cream sauce', 'escalope'})
# frozenset({'escalope', 'pasta'})
# frozenset({'herb & pepper', 'ground beef'})
# frozenset({'tomato sauce', 'ground beef'})
# frozenset({'whole wheat pasta', 'olive oil'})
# frozenset({'shrimp', 'pasta'})
# frozenset({'chicken', 'light cream', 'nan'})
# frozenset({'frozen vegetables', 'chocolate', 'shrimp'})
# frozenset({'cooking oil', 'spaghetti', 'ground beef'})
# frozenset({'nan', 'mushroom cream sauce', 'escalope'})
# frozenset({'nan', 'escalope', 'pasta'})
# frozenset({'frozen vegetables', 'spaghetti', 'ground beef'})
# frozenset({'frozen vegetables', 'milk', 'olive oil'})
# frozenset({'frozen vegetables', 'mineral water', 'shrimp'})
# frozenset({'frozen vegetables', 'spaghetti', 'olive oil'})
# frozenset({'frozen vegetables', 'spaghetti', 'shrimp'})
# frozenset({'frozen vegetables', 'spaghetti', 'tomatoes'})
# frozenset({'grated cheese', 'spaghetti', 'ground beef'})
# frozenset({'herb & pepper', 'mineral water', 'ground beef'})
# frozenset({'herb & pepper', 'nan', 'ground beef'})
# frozenset({'herb & pepper', 'spaghetti', 'ground beef'})
# frozenset({'milk', 'ground beef', 'olive oil'})
# frozenset({'nan', 'tomato sauce', 'ground beef'})
# frozenset({'spaghetti', 'ground beef', 'shrimp'})
# frozenset({'milk', 'spaghetti', 'olive oil'})
# frozenset({'soup', 'mineral water', 'olive oil'})
# frozenset({'whole wheat pasta', 'nan', 'olive oil'})
# frozenset({'nan', 'shrimp', 'pasta'})
# frozenset({'pancakes', 'spaghetti', 'olive oil'})
# frozenset({'frozen vegetables', 'chocolate', 'nan', 'shrimp'})
# frozenset({'nan', 'cooking oil', 'spaghetti', 'ground beef'})
# frozenset({'frozen vegetables', 'spaghetti', 'nan', 'ground beef'})
# frozenset({'frozen vegetables', 'spaghetti', 'milk', 'mineral water'})
# frozenset({'frozen vegetables', 'nan', 'milk', 'olive oil'})
# frozenset({'frozen vegetables', 'nan', 'mineral water', 'shrimp'})
# frozenset({'frozen vegetables', 'nan', 'spaghetti', 'olive oil'})
# frozenset({'frozen vegetables', 'nan', 'spaghetti', 'shrimp'})
# frozenset({'frozen vegetables', 'nan', 'spaghetti', 'tomatoes'})
# frozenset({'grated cheese', 'spaghetti', 'nan', 'ground beef'})
# frozenset({'herb & pepper', 'mineral water', 'nan', 'ground beef'})
# frozenset({'herb & pepper', 'nan', 'spaghetti', 'ground beef'})
# frozenset({'nan', 'milk', 'ground beef', 'olive oil'})
# frozenset({'nan', 'spaghetti', 'ground beef', 'shrimp'})
# frozenset({'nan', 'milk', 'spaghetti', 'olive oil'})
# frozenset({'nan', 'soup', 'mineral water', 'olive oil'})
# frozenset({'nan', 'pancakes', 'spaghetti', 'olive oil'})
# frozenset({'nan', 'mineral water', 'spaghetti', 'frozen vegetables', 'milk'})

# %%
for item in results:
    pair=item[0]
    items=[g for g in pair]
    print('Rule is',items[0],'-->',items[1])
# Out:
# Rule is chicken --> light cream
# Rule is mushroom cream sauce --> escalope
# Rule is escalope --> pasta
# Rule is herb & pepper --> ground beef
# Rule is tomato sauce --> ground beef
# Rule is whole wheat pasta --> olive oil
# Rule is shrimp --> pasta
# Rule is chicken --> light cream
# Rule is frozen vegetables --> chocolate
# Rule is cooking oil --> spaghetti
# Rule is nan --> mushroom cream sauce
# Rule is nan --> escalope
# Rule is frozen vegetables --> spaghetti
# Rule is frozen vegetables --> milk
# Rule is frozen vegetables --> mineral water
# Rule is frozen vegetables --> spaghetti
# Rule is frozen vegetables --> spaghetti
# Rule is frozen vegetables --> spaghetti
# Rule is grated cheese --> spaghetti
# Rule is herb & pepper --> mineral water
# Rule is herb & pepper --> nan
# Rule is herb & pepper --> spaghetti
# Rule is milk --> ground beef
# Rule is nan --> tomato sauce
# Rule is spaghetti --> ground beef
# Rule is milk --> spaghetti
# Rule is soup --> mineral water
# Rule is whole wheat pasta --> nan
# Rule is nan --> shrimp
# Rule is pancakes --> spaghetti
# Rule is frozen vegetables --> chocolate
# Rule is nan --> cooking oil
# Rule is frozen vegetables --> spaghetti
# Rule is frozen vegetables --> spaghetti
# Rule is frozen vegetables --> nan
# Rule is frozen vegetables --> nan
# Rule is frozen vegetables --> nan
# Rule is frozen vegetables --> nan
# Rule is frozen vegetables --> nan
# Rule is grated cheese --> spaghetti
# Rule is herb & pepper --> mineral water
# Rule is herb & pepper --> nan
# Rule is nan --> milk
# Rule is nan --> spaghetti
# Rule is nan --> milk
# Rule is nan --> soup
# Rule is nan --> pancakes
# Rule is nan --> mineral water

# %%
for item in results:
    pair=item[0]
    items=[g for g in pair]
    print('Rule is',items[0],'-->',items[1])
    print('Support is',str(item[1]))
    print('Confidence is',str(item[2][0][2]))
    print('Lift is',str(item[2][0][3]))
    print("|")
# Out:
# Rule is chicken --> light cream
# Support is 0.004533333333333334
# Confidence is 0.2905982905982906
# Lift is 4.843304843304844
# |
# Rule is mushroom cream sauce --> escalope
# Support is 0.005733333333333333
# Confidence is 0.30069930069930073
# Lift is 3.7903273197390845
# |
# Rule is escalope --> pasta
# Support is 0.005866666666666667
# Confidence is 0.37288135593220345
# Lift is 4.700185158809287
# |
# Rule is herb & pepper --> ground beef
# Support is 0.016
# Confidence is 0.3234501347708895
# Lift is 3.2915549671393096
# |
# Rule is tomato sauce --> ground beef
# Support is 0.005333333333333333
# Confidence is 0.37735849056603776
# Lift is 3.840147461662528
# |
# Rule is whole wheat pasta --> olive oil
# Support is 0.008
# Confidence is 0.2714932126696833
# Lift is 4.130221288078346
# |
# Rule is shrimp --> pasta
# Support is 0.005066666666666666
# Confidence is 0.3220338983050848
# Lift is 4.514493901473151
# |
# Rule is chicken --> light cream
# Support is 0.004533333333333334
# Confidence is 0.2905982905982906
# Lift is 4.843304843304844
# |
# Rule is frozen vegetables --> chocolate
# Support is 0.005333333333333333
# Confidence is 0.23255813953488372
# Lift is 3.260160834601174
# |
# Rule is cooking oil --> spaghetti
# Support is 0.0048
# Confidence is 0.5714285714285714
# Lift is 3.281557646029315
# |
# Rule is nan --> mushroom cream sauce
# Support is 0.005733333333333333
# Confidence is 0.30069930069930073
# Lift is 3.7903273197390845
# |
# Rule is nan --> escalope
# Support is 0.005866666666666667
# Confidence is 0.37288135593220345
# Lift is 4.700185158809287
# |
# Rule is frozen vegetables --> spaghetti
# Support is 0.008666666666666666
# Confidence is 0.3110047846889952
# Lift is 3.164906221394116
# |
# Rule is frozen vegetables --> milk
# Support is 0.0048
# Confidence is 0.20338983050847456
# Lift is 3.094165778526489
# |
# Rule is frozen vegetables --> mineral water
# Support is 0.0072
# Confidence is 0.3068181818181818
# Lift is 3.2183725365543547
# |
# Rule is frozen vegetables --> spaghetti
# Support is 0.005733333333333333
# Confidence is 0.20574162679425836
# Lift is 3.1299436124887174
# |
# Rule is frozen vegetables --> spaghetti
# Support is 0.006
# Confidence is 0.21531100478468898
# Lift is 3.0183785717479763
# |
# Rule is frozen vegetables --> spaghetti
# Support is 0.006666666666666667
# Confidence is 0.23923444976076555
# Lift is 3.497579674864993
# |
# Rule is grated cheese --> spaghetti
# Support is 0.005333333333333333
# Confidence is 0.3225806451612903
# Lift is 3.282706701098612
# |
# Rule is herb & pepper --> mineral water
# Support is 0.006666666666666667
# Confidence is 0.390625
# Lift is 3.975152645861601
# |
# Rule is herb & pepper --> nan
# Support is 0.016
# Confidence is 0.3234501347708895
# Lift is 3.2915549671393096
# |
# Rule is herb & pepper --> spaghetti
# Support is 0.0064
# Confidence is 0.3934426229508197
# Lift is 4.003825878061259
# |
# Rule is milk --> ground beef
# Support is 0.004933333333333333
# Confidence is 0.22424242424242424
# Lift is 3.411395906324912
# |
# Rule is nan --> tomato sauce
# Support is 0.005333333333333333
# Confidence is 0.37735849056603776
# Lift is 3.840147461662528
# |
# Rule is spaghetti --> ground beef
# Support is 0.006
# Confidence is 0.5232558139534884
# Lift is 3.004914704939635
# |
# Rule is milk --> spaghetti
# Support is 0.0072
# Confidence is 0.20300751879699247
# Lift is 3.0883496774390333
# |
# Rule is soup --> mineral water
# Support is 0.0052
# Confidence is 0.2254335260115607
# Lift is 3.4295161157945335
# |
# Rule is whole wheat pasta --> nan
# Support is 0.008
# Confidence is 0.2714932126696833
# Lift is 4.130221288078346
# |
# Rule is nan --> shrimp
# Support is 0.005066666666666666
# Confidence is 0.3220338983050848
# Lift is 4.514493901473151
# |
# Rule is pancakes --> spaghetti
# Support is 0.005066666666666666
# Confidence is 0.20105820105820105
# Lift is 3.0586947422647217
# |
# Rule is frozen vegetables --> chocolate
# Support is 0.005333333333333333
# Confidence is 0.23255813953488372
# Lift is 3.260160834601174
# |
# Rule is nan --> cooking oil
# Support is 0.0048
# Confidence is 0.5714285714285714
# Lift is 3.281557646029315
# |
# Rule is frozen vegetables --> spaghetti
# Support is 0.008666666666666666
# Confidence is 0.3110047846889952
# Lift is 3.164906221394116
# |
# Rule is frozen vegetables --> spaghetti
# Support is 0.004533333333333334
# Confidence is 0.28813559322033905
# Lift is 3.0224013274860737
# |
# Rule is frozen vegetables --> nan
# Support is 0.0048
# Confidence is 0.20338983050847456
# Lift is 3.094165778526489
# |
# Rule is frozen vegetables --> nan
# Support is 0.0072
# Confidence is 0.3068181818181818
# Lift is 3.2183725365543547
# |
# Rule is frozen vegetables --> nan
# Support is 0.005733333333333333
# Confidence is 0.20574162679425836
# Lift is 3.1299436124887174
# |
# Rule is frozen vegetables --> nan
# Support is 0.006
# Confidence is 0.21531100478468898
# Lift is 3.0183785717479763
# |
# Rule is frozen vegetables --> nan
# Support is 0.006666666666666667
# Confidence is 0.23923444976076555
# Lift is 3.497579674864993
# |
# Rule is grated cheese --> spaghetti
# Support is 0.005333333333333333
# Confidence is 0.3225806451612903
# Lift is 3.282706701098612
# |
# Rule is herb & pepper --> mineral water
# Support is 0.006666666666666667
# Confidence is 0.390625
# Lift is 3.975152645861601
# |
# Rule is herb & pepper --> nan
# Support is 0.0064
# Confidence is 0.3934426229508197
# Lift is 4.003825878061259
# |
# Rule is nan --> milk
# Support is 0.004933333333333333
# Confidence is 0.22424242424242424
# Lift is 3.411395906324912
# |
# Rule is nan --> spaghetti
# Support is 0.006
# Confidence is 0.5232558139534884
# Lift is 3.004914704939635
# |
# Rule is nan --> milk
# Support is 0.0072
# Confidence is 0.20300751879699247
# Lift is 3.0883496774390333
# |
# Rule is nan --> soup
# Support is 0.0052
# Confidence is 0.2254335260115607
# Lift is 3.4295161157945335
# |
# Rule is nan --> pancakes
# Support is 0.005066666666666666
# Confidence is 0.20105820105820105
# Lift is 3.0586947422647217
# |
# Rule is nan --> mineral water
# Support is 0.004533333333333334
# Confidence is 0.28813559322033905
# Lift is 3.0224013274860737
# |

# %%
#Putting our results in a dataframe
Rule=[]
Confidence=[]
Support=[]
Lift=[]
for item in results:
    pair=item[0]
    items=[g for g in pair]
    Rule.append(items)
    Support.append(str(item[1]))
    Confidence.append(str(item[2][0][2]))
    Lift.append(str(item[2][0][3]))

# %%
dct={'Rule':Rule,
     'Confidence':Confidence,
     'Lift':Lift,
    'Support':Support}
df1=pd.DataFrame(dct)

# %%
df1.head()
# Out:
#                                Rule           Confidence                Lift  \
# 0            [chicken, light cream]   0.2905982905982906   4.843304843304844
# 1  [mushroom cream sauce, escalope]  0.30069930069930073  3.7903273197390845
# 2                 [escalope, pasta]  0.37288135593220345   4.700185158809287
# 3      [herb & pepper, ground beef]   0.3234501347708895  3.2915549671393096
# 4       [tomato sauce, ground beef]  0.37735849056603776   3.840147461662528
#
#                 Support
# 0  0.004533333333333334
# 1  0.005733333333333333
# 2  0.005866666666666667
# 3                 0.016
# 4  0.005333333333333333
